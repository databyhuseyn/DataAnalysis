# %% [markdown]
# <a href="https://colab.research.google.com/github/databyhuseyn/DataAnalysis/blob/main/introduction_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import os

# %%
cars = pd.Series(["Tesla", "Ferrari", "Bugatti"])
cars
# Out:
# 0      Tesla
# 1    Ferrari
# 2    Bugatti
# dtype: object

# %%
colours = pd.Series(["Pink","Red","Black"])
colours
# Out:
# 0     Pink
# 1      Red
# 2    Black
# dtype: object

# %%
cars = pd.DataFrame({'cars':cars,
                     'colours': colours})

cars
# Out:
#       cars colours
# 0    Tesla    Pink
# 1  Ferrari     Red
# 2  Bugatti   Black

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/car-sales.csv
# Out:
# --2024-01-16 11:56:13--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv’
#
# car-sales.csv       100%[===================>]     369  --.-KB/s    in 0s
#
# 2024-01-16 11:56:13 (4.30 MB/s) - ‘car-sales.csv’ saved [369/369]

# %%
car_sales = pd.read_csv("/content/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
pd.DataFrame(car_sales["Price"])
price_table = pd.DataFrame(car_sales["Price"])
price_table
# Out:
#         Price
# 0   $4,000.00
# 1   $5,000.00
# 2   $7,000.00
# 3  $22,000.00
# 4   $3,500.00
# 5   $4,500.00
# 6   $7,500.00
# 7   $7,000.00
# 8   $6,250.00
# 9   $9,700.00

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %%
car_sales["Make"].value_counts()
# Out:
# Toyota    4
# Honda     3
# Nissan    2
# BMW       1
# Name: Make, dtype: int64

# %%
car_sales["Doors"].mean()
# Out:
# 4.0

# %%
car_sales.mean()
# Out:
# <ipython-input-59-04f02239622f>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales[car_sales["Make"] == "Toyota" ]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00
